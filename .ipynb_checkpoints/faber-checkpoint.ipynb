# %%
from pynq import Overlay
from pynq import allocate
import numpy as np
import random

# %%
from faber.image import SobelGradient
from faber.losses import MutualInformationLossNative, MutualInformationLossFPGA, MutualInformationLoss
from faber.optimizers import GradientDescentOptimizer
from faber.transforms import RotateShiftTransform

import pydicom
import cv2
from matplotlib import pyplot as plt
from tqdm import tqdm
from timeit import default_timer as timer

# %%
overlay = Overlay('./matrix/design_1_wrapper.bit')

# %%
mi_ip = overlay.mutual_information_d_0

# %%
size = 512
image_dim = size*size
matrix_dim = 256*256
image_1 = allocate(shape=(image_dim,), dtype=np.uint8)
image_2 = allocate(shape=(image_dim,), dtype=np.uint8)
res = allocate(shape=(matrix_dim,), dtype=np.float32)

# %%
dcm1 = pydicom.dcmread('IM10_a.dcm')
img1 = cv2.resize(dcm1.pixel_array, dsize=(size,size))
img1 = cv2.normalize(img1, None, 0, 255, cv2.NORM_MINMAX, dtype=cv2.CV_8U)

dcm2 = pydicom.dcmread('IM10_b.dcm')
img2 = cv2.resize(dcm2.pixel_array, dsize=(size,size))
img2 = cv2.normalize(img2, None, 0, 255, cv2.NORM_MINMAX, dtype=cv2.CV_8U)

# %%
fig, ax = plt.subplots(1,2)
fig.set_size_inches(18,9)
ax[0].imshow(img1)
ax[1].imshow(img2)

# %%
lr = 1e-4
alpha = 1e-5

transform = RotateShiftTransform(alpha=alpha)
grad = SobelGradient(k=3)
loss = MutualInformationLossFPGA(mi_ip, image_1, image_2, res)
optimizer = GradientDescentOptimizer(transform, loss, grad, lr, 1)

# %%
image_1[:] = img1.flatten()
image_1.flush()

# %%
for i in tqdm(range(10)):
    optimizer.step(img1, img2)
# Out:
# 100%|██████████| 10/10 [00:10<00:00,  1.05s/it]

# %%
final = optimizer.transform(img2)

# %%
optimizer.transform.parameters
# Out:
# array([ 0.02690126,  3.3175473 , -8.58302805])

# %%
fig, ax = plt.subplots(1,2)
fig.set_size_inches(18,9)
ax[0].imshow(img1)
ax[1].imshow(final)

# %%
transform = RotateShiftTransform(alpha=alpha)
grad = SobelGradient(k=3)
loss = MutualInformationLoss()
optimizer = GradientDescentOptimizer(transform, loss, grad, lr, 1)

# %%
for i in tqdm(range(10)):
    optimizer.step(img1, img2)
# Out:
# 100%|██████████| 10/10 [01:06<00:00,  6.63s/it]

# %%
final = optimizer.transform(img2)

# %%
optimizer.transform.parameters
# Out:
# array([ 0.01773196,  2.277134  , -5.58002425])

# %%
fig, ax = plt.subplots(1,2)
fig.set_size_inches(18,9)
ax[0].imshow(img1)
ax[1].imshow(final)
